# %%
# !pip install moviepy speechrecognition google-cloud-speech vosk
# Out:
# Requirement already satisfied: moviepy in d:\installed_software\anaconda\lib\site-packages (2.1.2)
# Requirement already satisfied: speechrecognition in d:\installed_software\anaconda\lib\site-packages (3.14.2)
# Requirement already satisfied: google-cloud-speech in d:\installed_software\anaconda\lib\site-packages (2.32.0)
# Requirement already satisfied: vosk in d:\installed_software\anaconda\lib\site-packages (0.3.45)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (2.33.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (1.26.4)
# Requirement already satisfied: proglog<=1.0.0 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (0.1.11)
# Requirement already satisfied: python-dotenv>=0.10 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (0.21.0)
# Requirement already satisfied: pillow<11.0,>=9.2.0 in d:\installed_software\anaconda\lib\site-packages (from moviepy) (10.4.0)
# Requirement already satisfied: typing-extensions in d:\installed_software\anaconda\lib\site-packages (from speechrecognition) (4.11.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in d:\installed_software\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-speech) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in d:\installed_software\anaconda\lib\site-packages (from google-cloud-speech) (2.39.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in d:\installed_software\anaconda\lib\site-packages (from google-cloud-speech) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in d:\installed_software\anaconda\lib\site-packages (from google-cloud-speech) (5.29.4)
# Requirement already satisfied: cffi>=1.0 in d:\installed_software\anaconda\lib\site-packages (from vosk) (1.17.1)
# Requirement already satisfied: requests in d:\installed_software\anaconda\lib\site-packages (from vosk) (2.32.3)
# Requirement already satisfied: srt in d:\installed_software\anaconda\lib\site-packages (from vosk) (3.5.3)
# Requirement already satisfied: tqdm in d:\installed_software\anaconda\lib\site-packages (from vosk) (4.66.5)
# Requirement already satisfied: websockets in d:\installed_software\anaconda\lib\site-packages (from vosk) (15.0.1)
# Requirement already satisfied: pycparser in d:\installed_software\anaconda\lib\site-packages (from cffi>=1.0->vosk) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\installed_software\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-speech) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in d:\installed_software\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-speech) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in d:\installed_software\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-speech) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\installed_software\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-speech) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\installed_software\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-speech) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\installed_software\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-speech) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\installed_software\anaconda\lib\site-packages (from requests->vosk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\installed_software\anaconda\lib\site-packages (from requests->vosk) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\installed_software\anaconda\lib\site-packages (from requests->vosk) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\installed_software\anaconda\lib\site-packages (from requests->vosk) (2024.12.14)
# Requirement already satisfied: colorama in d:\installed_software\anaconda\lib\site-packages (from tqdm->vosk) (0.4.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\installed_software\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-speech) (0.4.8)

# %%
# The code installs several Python libraries needed for audio and video processing:

# moviepy: Used for video editing and extracting audio from videos.

# speechrecognition: Used for transcribing audio into text.

# google-cloud-speech: Google’s cloud API for speech-to-text, though it doesn't appear to be used in the provided snippet.

# vosk: A speech recognition library for real-time transcription, which is actually used in the code.

import os
import moviepy.editor as mp
from vosk import Model, KaldiRecognizer
import wave
import json

# Function to extract audio from video and save as a WAV file
def extract_audio_from_video(video_path, audio_output_path):
    video = mp.VideoFileClip(video_path)
    video.audio.write_audiofile(audio_output_path)

# Function to transcribe audio using Vosk
def transcribe_audio(audio_path, search_word):
    # Load Vosk model (make sure the model is downloaded from Vosk's official page)
    if not os.path.exists("vosk-model-small-en-us-0.15"):
        print("Please download the model from https://alphacephei.com/vosk/models and unpack it to 'vosk-model-small-en-us-0.15' directory.")
        return

    model = Model("vosk-model-small-en-us-0.15")
    
    # Open the audio file
    wf = wave.open(audio_path, "rb")
    
    # Ensure the audio is mono-channel and with a proper sample rate
    if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getframerate() != 16000:
        print("Audio file must be WAV format mono PCM.")
        return
    
    recognizer = KaldiRecognizer(model, wf.getframerate())
    recognizer.SetWords(True)  # Enable word timestamps

    transcription = ""
    word_found = False
    search_word = search_word.lower()

    # Process the audio file in chunks
    while True:
        data = wf.readframes(4000)
        if len(data) == 0:
            break

        if recognizer.AcceptWaveform(data):
            result = json.loads(recognizer.Result())
            transcription += result.get("text", "")
            # Check if the word is found in the result
            for word in result.get("result", []):
                if search_word in word["word"].lower():
                    word_found = True
                    print(f"Found '{search_word}' at timestamp {word['start']}s - {word['end']}s")

    # Final partial results
    final_result = json.loads(recognizer.FinalResult())
    transcription += final_result.get("text", "")
    
    # Search the final transcript if not already found
    if not word_found and search_word in transcription.lower():
        print(f"'{search_word}' found in the audio.")

    wf.close()

    return transcription

# Main workflow
video_path = "test_video.mp4"
audio_output_path = "extracted_audio.wav"
search_word = "example"

# Step 1: Extract audio from the video
extract_audio_from_video(video_path, audio_output_path)

# Step 2: Transcribe and search for the word in the audio
transcription = transcribe_audio(audio_output_path, search_word)

# Print the full transcription if needed
print("\nFull transcription:\n", transcription)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import moviepy.editor as mp
#       3 from vosk import Model, KaldiRecognizer
#       4 import wave
#
# ModuleNotFoundError: No module named 'moviepy.editor'
